# %% [markdown]
# ## ACT Report

# %% [markdown]
# ### Name : Abubakar Keita
# - __Project: Act Report__
# - __Location: Monrovia, Liberia, West Africa__

# %% [markdown]
# ## Introduction

# %% [markdown]
# As part of the data wrangling project's intructions, at least three (3) insights and one (1) visualization must be produced. This report communicates the insights and displays the visualization(s) produced from my wrangled data. The dataset that I analyzed and visualized is the tweet archive of Twitter user dog_rates, also known as WeRateDogs. According Udacity, WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. The denominators of the rating is almost always 10 while the numerators are normally greater then 10. More than 4 million followers follow WeRateDogs and it has received international media coverage.
#
# For the three insights, the following three questions are answered.
# 1. Which breed of dog received the highest number of tweets?
# 2. Among the 4 sstages mentioned in the data, dogs in whcih stage recived the highest tweets?
# 3. Are there correlation bewteen likes (favorite counts) and and retweet count?
# 4. What are the top 15 average rated breed?

# %% [markdown]
# ## _Insight One_
# From the scatter plot, I think there is positive correlation between the number of likes and the number of retweets of the tweet archive of Twitter user dog_rates. Further cleaning of this data set would clearly illustrate this insight. As the number of retweent increases, the favotite count ('Likes) also increases.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## _Insight two_
#
# There are four life stages that the dogs in WeRateDogs undergo. They are pupper, doggo, puppo and floofer. And dogs in the pupper stage got the highest tweets from WeRateDogs  Twitter users. Dogs in Pupper stage got 153 more tweets than dogs in the other life stages. Doggo and pupper are affectionate terms for dog and puppy used in the internet slang called DoggoLingo (Dictionay.com)
#
# ![Dog_stages.PNG](attachment:Dog_stages.PNG)

# %% [markdown]
# ## _Insight Three_

# %% [markdown]
# The top ten breed with highest tweets are illustrated below. Obviously, the Golden Retriever is the most tweeted breeds found, followed by Labrador Retrieved, Pembroke and so on.
#
# ![Top_10_breed.PNG](attachment:Top_10_breed.PNG)

# %% [markdown]
# ## _Insight Four_

# %% [markdown]
# Based on the graph below, most of the top 15 rated breeds fall between 1.0 and 1.5 whcih clearly support the fact the rating numerator is almost always greater than 10 and the rating denominator is almost always equal to 10. The Clumber, also known as Clumber Spaniel is the top rated breed. The Clumber Spaniel is a breed of dog of the spaniel type, developed in the United Kingdom, (wikipedia, n.d). According to Wikipedia.org, the name of the breed is taken from Clumber Park in Nottinghamshire where the breed was first developed.
#
# ![Average_rated_breeds.PNG](attachment:Average_rated_breeds.PNG)

# %% [markdown]
# To summarize,  four insights and four visualizations were produced from the tweet archive of Twitter user dog_rates. Pupper stage was the most tweeted stage, the golden retriever is the most tweeted dog's breed and cluber is the top most rated breed. The project was a very good exploration of my data wrangling skills.

# %% [markdown]
# References:
# 1. https://en.wikipedia.org/wiki/Clumber_Spaniel
# 2. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.SeriesGroupBy.nlargest.html
# 3. https://www.dictionary.com/e/slang/doggo/
# 4. https://towardsdatascience.com/adding-image-files-inside-an-ipython-notebook-python-and-r-2ba089a658b8
# 6. https://knowyourmeme.com/memes/theyre-good-dogs-brent
# 7. https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html
# 8. https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/
